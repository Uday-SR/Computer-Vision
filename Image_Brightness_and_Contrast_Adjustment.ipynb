# %% [markdown]
# <a href="https://colab.research.google.com/github/Uday-SR/Computer-Vision/blob/main/Image_Brightness_and_Contrast_Adjustment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bc05cd53-407e-4f90-8837-d57404f1f38a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc05cd53-407e-4f90-8837-d57404f1f38a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread('goofy.jpg')

# %%
#Increase Brightness

bright = cv2.convertScaleAbs(img, alpha=1.0, beta=50)
cv2_imshow(bright)
# Out:
# <PIL.Image.Image image mode=RGB size=200x300>

# %%
#Decrease Brightness

dark = cv2.convertScaleAbs(img, alpha=1.0, beta=-50)
cv2_imshow(dark)
# Out:
# <PIL.Image.Image image mode=RGB size=200x300>

# %%
#Increase Contrast

high_contrast = cv2.convertScaleAbs(img, alpha=1.5, beta=0)
cv2_imshow(high_contrast)
# Out:
# <PIL.Image.Image image mode=RGB size=200x300>

# %%
#Decrease Contrast

low_contrast = cv2.convertScaleAbs(img, alpha=0.5, beta=0)
cv2_imshow(low_contrast)
# Out:
# <PIL.Image.Image image mode=RGB size=200x300>

# %%
#Compare image quality

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(bright, cv2.COLOR_BGR2RGB))
plt.title("Brighter")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(dark, cv2.COLOR_BGR2RGB))
plt.title("Darker")
plt.axis("off")

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(high_contrast, cv2.COLOR_BGR2RGB))
plt.title("High Contrast")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(low_contrast, cv2.COLOR_BGR2RGB))
plt.title("Low Contrast")
plt.axis("off")

plt.show()

# %%
#Save enhanced images

cv2.imwrite('bright.jpg', bright)
cv2.imwrite('dark.jpg', dark)
cv2.imwrite('highContrast.jpg', high_contrast)
cv2.imwrite('lowContrast.jpg', low_contrast)
# Out:
# True
